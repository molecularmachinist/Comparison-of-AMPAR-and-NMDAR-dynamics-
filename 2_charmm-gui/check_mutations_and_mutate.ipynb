# %%
import __main__
__main__.pymol_argv = [ 'pymol', '-qc'] 

import sys, time, os
import itertools
import pymol
import lil_helpers as lh

# %%
# %%bash
# pwd
# Out:
# /home/pirnessa/UH/Work/Comparison-of-AMPAR-and-NMDAR-dynamics/Building_systems/2_charmm-gui

# %%
def mutate_protein_pdb(pdbIn,pdbOut,arr_iRes,arr_mutRes,arr_chain=['A']):
    """ Mutates pdb anf outputs pdb """
    
    
    
    
    
    # Name of the pdb file ( without path and .pdb)
    pdbName = pdbIn.split('/')[-1].split('.')[0]
    
    # Load the structure
    pymol.cmd.load(pdbIn, pdbName)
    pymol.cmd.wizard('mutagenesis')
    for iRes, mutRes, chain in zip(arr_iRes,arr_mutRes,arr_chain):
        print(iRes, mutRes, chain)
        
        # Minty fresh
        pymol.cmd.do('refresh_wizard')

        # Set target residue type
        pymol.cmd.get_wizard().set_mode(str(mutRes))

        # Select residue
        selection = '/{}//{}/{}'.format(pdbName,chain,iRes)

        # Notify the wizard about the selection
        pymol.cmd.get_wizard().do_select(selection)

        # Select frame 1
        pymol.cmd.frame('1')

        # Apply the mutation
        pymol.cmd.get_wizard().apply()
    

    # Create
    pymol.cmd.save(pdbOut)
    
    # and destroy
    pymol.cmd.delete('all')

# %%
pdb = '../Add_missing_residues_1/AMPA/5weo_cleaned_filled_pymol_aligned_glutamate.pdb'
ABCD = lh.seq_in_chains(pdb,chains='ABCD')

# %%
i0 = 1
arr_iRes,arr_mutRes,arr_chain =[], [], []

for chain in 'ABCD':
    hih = lh.diff_seq(ABCD[chain],lh.seq_ampa)
    
    for iRes, _, mutRes in hih:
        
        arr_iRes.append(iRes+i0)
        arr_mutRes.append(lh.one2three[mutRes])
        arr_chain.append(chain)
    
    i0 += len(ABCD[chain])

# %%
pdb_out = '5weo_cleaned_filled_pymol_aligned_glutamate_mutated.pdb'

# %%
mutate_protein_pdb(pdb,pdb_out,arr_iRes,arr_mutRes,arr_chain)
# Out:
# 167 MET A
# Selected!
#  Mutagenesis: 11 rotamers loaded.
#  Rotamer 6/11, strain=-19.94
# 232 ASN A
# Selected!
#  Mutagenesis: 11 rotamers loaded.
#  Rotamer 9/11, strain=1.76
# 267 THR A
# Selected!
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 2/3, strain=12.16
# 373 VAL A
# Selected!
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 3/3, strain=10.33
# 375 GLY A
# Selected!
#  Mutagenesis: no rotamers found in library.
# 376 ASN A
# Selected!
#  Mutagenesis: 10 rotamers loaded.
#  Rotamer 6/10, strain=2.54
# 383 ASN A
# Selected!
#  Mutagenesis: 11 rotamers loaded.
#  Rotamer 10/11, strain=-4.72
# 734 ARG A
# Selected!
#  Mutagenesis: 21 rotamers loaded.
#  Rotamer 6/21, strain=0.48
# 735 ASN A
# Selected!
#  Mutagenesis: 8 rotamers loaded.
#  Rotamer 7/8, strain=-1.11
# 736 ALA A
# Selected!
#  Mutagenesis: no rotamers found in library.
# 745 ASN A
# Selected!
#  Mutagenesis: 10 rotamers loaded.
#  Rotamer 8/10, strain=-14.64
# 749 LEU A
# Selected!
#  Mutagenesis: 4 rotamers loaded.
#  Rotamer 2/4, strain=8.84
# 766 SER A
# Selected!
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=9.44
# 767 GLY A
# Selected!
#  Mutagenesis: no rotamers found in library.
# 768 GLY A
# Selected!
#  Mutagenesis: no rotamers found in library.
# 769 GLY A
# Selected!
#  Mutagenesis: no rotamers found in library.
# 770 ASP A
# Selected!
#  Mutagenesis: 5 rotamers loaded.
#  Rotamer 5/5, strain=3.82
# 978 MET B
# Selected!
#  Mutagenesis: 13 rotamers loaded.
#  Rotamer 13/13, strain=-45.49
# 1043 ASN B
# Selected!
#  Mutagenesis: 10 rotamers loaded.
#  Rotamer 8/10, strain=-3.46
# 1078 THR B
# Selected!
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 1/2, strain=13.10
# 1184 VAL B
# Selected!
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 3/3, strain=6.16
# 1186 GLY B
# Selected!
#  Mutagenesis: no rotamers found in library.
# 1187 ASN B
# Selected!
#  Mutagenesis: 5 rotamers loaded.
#  Rotamer 3/5, strain=5.94
# 1194 ASN B
# Selected!
#  Mutagenesis: 9 rotamers loaded.
#  Rotamer 8/9, strain=-1.45
# 1545 ARG B
# Selected!
#  Mutagenesis: 21 rotamers loaded.
#  Rotamer 6/21, strain=0.78
# 1546 ASN B
# Selected!
#  Mutagenesis: 8 rotamers loaded.
#  Rotamer 7/8, strain=-1.11
# 1547 ALA B
# Selected!
#  Mutagenesis: no rotamers found in library.
# 1556 ASN B
# Selected!
#  Mutagenesis: 11 rotamers loaded.
#  Rotamer 11/11, strain=-13.34
# 1560 LEU B
# Selected!
#  Mutagenesis: 4 rotamers loaded.
#  Rotamer 2/4, strain=12.78
# 1577 SER B
# Selected!
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 1/3, strain=20.44
# 1578 GLY B
# Selected!
#  Mutagenesis: no rotamers found in library.
# 1579 GLY B
# Selected!
#  Mutagenesis: no rotamers found in library.
# 1580 GLY B
# Selected!
#  Mutagenesis: no rotamers found in library.
# 1581 ASP B
# Selected!
#  Mutagenesis: 7 rotamers loaded.
#  Rotamer 6/7, strain=-0.52
# 1788 MET C
# Selected!
#  Mutagenesis: 13 rotamers loaded.
#  Rotamer 13/13, strain=-45.49
# 1853 ASN C
# Selected!
#  Mutagenesis: 9 rotamers loaded.
#  Rotamer 8/9, strain=1.92
# 1888 THR C
# Selected!
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 2/2, strain=11.87
# 1994 VAL C
# Selected!
#  Mutagenesis: 1 rotamers loaded.
#  Rotamer 1/1, strain=21.49
# 1996 GLY C
# Selected!
#  Mutagenesis: no rotamers found in library.
# 1997 ASN C
# Selected!
#  Mutagenesis: 11 rotamers loaded.
#  Rotamer 11/11, strain=-13.28
# 2004 ASN C
# Selected!
#  Mutagenesis: 10 rotamers loaded.
#  Rotamer 8/10, strain=-2.61
# 2355 ARG C
# Selected!
#  Mutagenesis: 21 rotamers loaded.
#  Rotamer 6/21, strain=-0.17
# 2356 ASN C
# Selected!
#  Mutagenesis: 8 rotamers loaded.
#  Rotamer 7/8, strain=-1.11
# 2357 ALA C
# Selected!
#  Mutagenesis: no rotamers found in library.
# 2366 ASN C
# Selected!
#  Mutagenesis: 10 rotamers loaded.
#  Rotamer 8/10, strain=-14.64
# 2370 LEU C
# Selected!
#  Mutagenesis: 4 rotamers loaded.
#  Rotamer 2/4, strain=14.56
# 2387 SER C
# Selected!
#  Mutagenesis: 3 rotamers loaded.
#  Rotamer 2/3, strain=5.08
# 2388 GLY C
# Selected!
#  Mutagenesis: no rotamers found in library.
# 2389 GLY C
# Selected!
#  Mutagenesis: no rotamers found in library.
# 2390 GLY C
# Selected!
#  Mutagenesis: no rotamers found in library.
# 2391 ASP C
# Selected!
#  Mutagenesis: 7 rotamers loaded.
#  Rotamer 6/7, strain=-4.36
# 2599 MET D
# Selected!
#  Mutagenesis: 11 rotamers loaded.
#  Rotamer 6/11, strain=-19.94
# 2664 ASN D
# Selected!
#  Mutagenesis: 10 rotamers loaded.
#  Rotamer 10/10, strain=-5.04
# 2699 THR D
# Selected!
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 2/2, strain=11.44
# 2805 VAL D
# Selected!
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 1/2, strain=10.31
# 2807 GLY D
# Selected!
#  Mutagenesis: no rotamers found in library.
# 2808 ASN D
# Selected!
#  Mutagenesis: 6 rotamers loaded.
#  Rotamer 2/6, strain=5.05
# 2815 ASN D
# Selected!
#  Mutagenesis: 9 rotamers loaded.
#  Rotamer 8/9, strain=0.07
# 3166 ARG D
# Selected!
#  Mutagenesis: 21 rotamers loaded.
#  Rotamer 6/21, strain=-2.95
# 3167 ASN D
# Selected!
#  Mutagenesis: 8 rotamers loaded.
#  Rotamer 7/8, strain=-1.11
# 3168 ALA D
# Selected!
#  Mutagenesis: no rotamers found in library.
# 3177 ASN D
# Selected!
#  Mutagenesis: 10 rotamers loaded.
#  Rotamer 10/10, strain=-12.87
# 3181 LEU D
# Selected!
#  Mutagenesis: 5 rotamers loaded.
#  Rotamer 1/5, strain=5.91
# 3198 SER D
# Selected!
#  Mutagenesis: 2 rotamers loaded.
#  Rotamer 1/2, strain=65.41
# 3199 GLY D
# Selected!
#  Mutagenesis: no rotamers found in library.
# 3200 GLY D
# Selected!
#  Mutagenesis: no rotamers found in library.
# 3201 GLY D
# Selected!
#  Mutagenesis: no rotamers found in library.
# 3202 ASP D
# Selected!
#  Mutagenesis: 7 rotamers loaded.
#  Rotamer 5/7, strain=-7.36

# %%
i0 = 1
for chain in 'ABCD':
    print('\n\nChain:',chain)
    lh.print_diff_seq(ABCD[chain],lh.seq_ampa,i0=i0)
    
    i0 += len(ABCD[chain])
# Out:
# Chain: A
# Resid	seq1       seq2
# 167,	THR(T) !=  MET(M)
# 232,	GLU(E) !=  ASN(N)
# 267,	ALA(A) !=  THR(T)
# 373,	LEU(L) !=  VAL(V)
# 375,	GLU(E) !=  GLY(G)
# 376,	ASP(D) !=  ASN(N)
# 383,	GLN(Q) !=  ASN(N)
# 734,	GLY(G) !=  ARG(R)
# 735,	THR(T) !=  ASN(N)
# 736,	PRO(P) !=  ALA(A)
# 745,	SER(S) !=  ASN(N)
# 749,	VAL(V) !=  LEU(L)
# 766,	ALA(A) !=  SER(S)
# 767,	LYS(K) !=  GLY(G)
# 768,	ASP(D) !=  GLY(G)
# 769,	SER(S) !=  GLY(G)
# 770,	GLY(G) !=  ASP(D)
#
#
# Chain: B
# Resid	seq1       seq2
# 978,	THR(T) !=  MET(M)
# 1043,	GLU(E) !=  ASN(N)
# 1078,	ALA(A) !=  THR(T)
# 1184,	LEU(L) !=  VAL(V)
# 1186,	GLU(E) !=  GLY(G)
# 1187,	ASP(D) !=  ASN(N)
# 1194,	GLN(Q) !=  ASN(N)
# 1545,	GLY(G) !=  ARG(R)
# 1546,	THR(T) !=  ASN(N)
# 1547,	PRO(P) !=  ALA(A)
# 1556,	SER(S) !=  ASN(N)
# 1560,	VAL(V) !=  LEU(L)
# 1577,	ALA(A) !=  SER(S)
# 1578,	LYS(K) !=  GLY(G)
# 1579,	ASP(D) !=  GLY(G)
# 1580,	SER(S) !=  GLY(G)
# 1581,	GLY(G) !=  ASP(D)
#
#
# Chain: C
# Resid	seq1       seq2
# 1788,	THR(T) !=  MET(M)
# 1853,	GLU(E) !=  ASN(N)
# 1888,	ALA(A) !=  THR(T)
# 1994,	LEU(L) !=  VAL(V)
# 1996,	GLU(E) !=  GLY(G)
# 1997,	ASP(D) !=  ASN(N)
# 2004,	GLN(Q) !=  ASN(N)
# 2355,	GLY(G) !=  ARG(R)
# 2356,	THR(T) !=  ASN(N)
# 2357,	PRO(P) !=  ALA(A)
# 2366,	SER(S) !=  ASN(N)
# 2370,	VAL(V) !=  LEU(L)
# 2387,	ALA(A) !=  SER(S)
# 2388,	LYS(K) !=  GLY(G)
# 2389,	ASP(D) !=  GLY(G)
# 2390,	SER(S) !=  GLY(G)
# 2391,	GLY(G) !=  ASP(D)
#
#
# Chain: D
# Resid	seq1       seq2
# 2599,	THR(T) !=  MET(M)
# 2664,	GLU(E) !=  ASN(N)
# 2699,	ALA(A) !=  THR(T)
# 2805,	LEU(L) !=  VAL(V)
# 2807,	GLU(E) !=  GLY(G)
# 2808,	ASP(D) !=  ASN(N)
# 2815,	GLN(Q) !=  ASN(N)
# 3166,	GLY(G) !=  ARG(R)
# 3167,	THR(T) !=  ASN(N)
# 3168,	PRO(P) !=  ALA(A)
# 3177,	SER(S) !=  ASN(N)
# 3181,	VAL(V) !=  LEU(L)
# 3198,	ALA(A) !=  SER(S)
# 3199,	LYS(K) !=  GLY(G)
# 3200,	ASP(D) !=  GLY(G)
# 3201,	SER(S) !=  GLY(G)
# 3202,	GLY(G) !=  ASP(D)

# %%
ABCD_new = lh.seq_in_chains(pdb_out,chains='ABCD')

i0 = 1
for chain in 'ABCD':
    print('\n\nChain:',chain)
    lh.print_diff_seq(ABCD_new[chain],lh.seq_ampa,i0=i0)
    
    i0 += len(ABCD_new[chain])
# Out:
# Chain: A
# Resid	seq1       seq2
#
#
# Chain: B
# Resid	seq1       seq2
#
#
# Chain: C
# Resid	seq1       seq2
#
#
# Chain: D
# Resid	seq1       seq2
